# %% [markdown]
# <img src="images/Picture0.png" width=200x />
#
# # Notebook 01 - Python Primer
#
# ## Instructions
#
# As you work through this notebook, you will be asked to run the code cells below. If you are new to jupyter, read the *User Interface Tour* found under the *Help* tab above. When highlighted in green when the mouse grabbed the focus of a cell, each code cell can be run using the *Ctrl-Enter* keys. Also see the README file provided with the Workshop.
#
# Material covered in this notebook:
# <ol>
# <li>How to save data to a variable in python
# <li>Types of data in python (focusing on intergers, floating point numbers, and strings)
# <li>How to print (view information) in python
# <li>An introduction to python lists (the basic way python stores multiple objects (strings, numbers, etc.) in a single variable
# <li> Conditionals in python: checking if things are true and false with if -else statements
# <li> Loops in python: how to loop through many different values using for and while statements
# </ol>
# Please make sure you are comfortable with this notebook before the start of Workshop #1.

# %% [markdown]
# # Variables

# %% [markdown]
# Any Python interpreter can be used as a calculator:

# %%
3 + 5 * 4 + 2/4

# %% [markdown]
# Notice how the '\*' and '/' operators have a higher precedence over '+' and '-'.
#
# These calculations are useful but we can do much more that that. When dealing with data, we often need to assign a value to a variable. In Python, we can assign a value to a variable, using the equals sign =. For example, we can track the weight of a patient who weighs 60 kilograms by assigning the value 60 to a variable weight_kg:

# %%
weight_kg = 60

# %% [markdown]
# From now on, whenever we use ```weight_kg```, Python will substitute the value we assigned to it. In layman’s terms, a variable is a name for a value.
#
# In Python, variable names:
#
# - can include letters, digits, and underscores
# - cannot start with a digit
# - are case sensitive.
#
# This means that, for example:
#
# - ```weight0``` is a valid variable name, whereas ```0weight``` is not
# - ```weight``` and ```Weight``` are two different variables
#
# Some variable names are illegal in Python because of they are reserved words. For example, you cannot use ```and```, ```else```, or ```print``` as the name of a variable. The full list of reserved words is available [here](https://docs.python.org/2/reference/lexical_analysis.html?highlight=keywords#keywords).

# %% [markdown]
# ### Exercise
#
# Which of the following will cause an error? Run the cells to check.

# %%
Age = 62

# %%
1st_name = 'Emily'

# %%
_baths = 3

# %%
class = 'algebra'

# %% [markdown]
# We can print the value of a variable using the ```print()``` command:

# %%
print(weight_kg)

# %% [markdown]
# ### Exercise
#
# Create a new variable and assign it a value. Print the value of the variable.

# %% [markdown]
# # Types of data

# %% [markdown]
# Python knows various types of data. Three common ones are:
#
# - integer numbers
# - floating point numbers, and
# - strings.
#
# In the example above, variable ```weight_kg``` has an integer value of 60. If we want to more precisely track the weight of our patient, we can use a floating point value by executing:

# %%
weight_kg = 60.3

# %% [markdown]
# To create a string, we add single or double quotes around some text. To identify and track a patient throughout our study, we can assign each person a unique identifier by storing it in a string:

# %%
patient_id = '001'

# %% [markdown]
# ### Exercise
#
# We can check the type of a variable using the ```type()``` command. Use it below to check the type of ```weight_kg``` and ```patient_id```. The first is done for you.

# %%
print(type(weight_kg))

# %% [markdown]
# # Using variables in Python

# %% [markdown]
# Once we have data stored with variable names, we can make use of it in calculations. We may want to store our patient’s weight in pounds as well as kilograms:

# %%
weight_lb = 2.2 * weight_kg

# %% [markdown]
# ### Exercise
#
# Print the value of ```weight_lb```.

# %% [markdown]
# We can also use some operators on strings:

# %%
patient_id = 'inflam_' + patient_id

# %% [markdown]
# ### Exercise
#
# Print the value of ```patient_id```.

# %% [markdown]
# # More advanced printing

# %% [markdown]
# We can print multiple items in one line:

# %%
print(patient_id, 'weight in kilograms:', weight_kg)

# %% [markdown]
# Moreover, we can do arithmetic with variables whereever an expression is expected. For example, using the print function:

# %%
print('weight in pounds:', 2.2 * weight_kg)

# %% [markdown]
# The above command, however, did not change the value of ```weight_kg```:

# %%
print(weight_kg)

# %% [markdown]
# To change the value of the weight_kg variable, we have to assign weight_kg a new value using the equals = sign:

# %%
weight_kg = 65.0
print('weight in kilograms is now:', weight_kg)

# %% [markdown]
# # Key Points
#
# - Basic data types in Python include integers, strings, and floating-point numbers.
#
# - Use ```variable = value``` to assign a value to a variable in order to record it in memory.
#
# - Variables are created on demand whenever a value is assigned to them.
#
# - Use ```print(something)``` to display the value of ```something```.

# %% [markdown]
# # Exercises

# %% [markdown]
# ### Calculate area and circumference of a circle

# %%
pi = 3.1415
r = 10.5

# %% [markdown]
# Calculate the area and circumference of a circle with radius ```r```. Print a description of your results.

# %% [markdown]
# ### Print a self-introduction

# %% [markdown]
# Create a new cell before the one below, and define the needed variables so that the code below runs.

# %%
print('Hello, my name is', my_name, 'and I attend', my_university, '.')

# %% [markdown]
# ## Python lists
# We create a list by putting values inside square brackets and separating the values with commas:

# %%
odds = [1, 3, 5, 7]
print('odds are:', odds)

# %% [markdown]
# We can access elements of a list using indices – numbered positions of elements in the list. These positions are numbered starting at 0, so the first element has an index of 0.

# %%
print('first element:', odds[0])
print('last element:', odds[3])
print('"-1" element:', odds[-1])

# %% [markdown]
# Yes, we can use negative numbers as indices in Python. When we do so, the index ```-1``` gives us the last element in the list, ```-2``` the second to last, and so on. Because of this, ```odds[3]``` and ```odds[-1]``` point to the same element here.

# %% [markdown]
# ### Exercise
#
# Create a list of each of the planets in our solar system ordered by distance from the sun (from least to greatest). Print the third planet in the list.
#
# *Hint:* The third planet is Earth. If you got Mars, go back and read the section above again carefully.

# %% [markdown]
# # Modifying lists
#
# We can change individual list elements:

# %%
names = ['Curie', 'Darwing', 'Turing']  # typo in Darwin's name
print('names is originally:', names)
names[1] = 'Darwin'  # correct the name
print('final value of names:', names)

# %% [markdown]
# We can also add elements to an existing list:

# %%
names.append('Einstein')
print(names)

# %% [markdown]
# Or combine two existing lists:

# %%
warm_colors = ['red', 'orange', 'yellow']
cold_colors = ['green', 'blue', 'purple']
combined_colors = warm_colors + cold_colors

# %% [markdown]
# ### Exercise
#
# Predict the what ```combined_colors``` will return, then print it to see if you were correct.

# %% [markdown]
# ### Conditional statements: if, elif, else
#  + The Python syntax for conditional execution of code uses the keywords `if`, `elif` (else if), `else`:
#
# ```python
# if statement1:
#     print("statement1 is True")
#
# elif statement2:
#     print("statement2 is True")
#
# else:
#     print("statement1 and statement2 are False")
# ```
#  + `If` statements don't decide on skipping or running the entire code. They only make decisions about a code block. Python uses the colon symbol (:) and indentation for showing where blocks of code begin and end.
#  + The condition is a Boolean expression, Logical operators AND, OR, NOT are used.

# %%
t = True
f = False
print(type(t))

# %%
print(t and f) # Logical AND;
print(t or f)  # Logical OR;
print(not t)   # Logical NOT;
print(t != f)  # Logical XOR (i.e. unequal);

# %%
if True:
    print("Yes")

# %%
if False:
    print("No")

# %% [markdown]
# -  Python comparison operators can be used for comparing values in the conditionals.
#     - A single equals sign `=` is used to assign values.
#     - a double equals sign `==` is used to test for equality.

# %%
a = 10
b = 0

print(a == b) # equal to
print(a != b) # is not equal to 
print(a > b)
print(a >= b)
print(a < b)
print(a <= b)

# %%
print('ex1 : ', 3 + 12 > 7 + 3)
print('ex2 : ', 5 + 10 * 3 > 7 + 3 * 20)
print('ex3 : ', 5 + 10 > 3 and 7 + 3 == 10)
print('ex4 : ', 5 + 10 > 0 and not 7 + 3 == 10)

# %% [markdown]
# ### Exercise
# Write a conditional statement below that prints YAY! if the number is greater than or equal to 90, MEH, if the number is between 80 and 90, or BOO! if the number is less than or equal to 80.

# %%
number = 95

# %% [markdown]
# ## Loops

# %% [markdown]
# ### **`for` loops**:
#
# - In Python, loops can be programmed in a number of different ways. The most common is the `for` loop, which is used together with iterable objects, such as lists. The basic syntax is:
#
# ```python
# a = [1, 2, 4, 3, 5]
# for i in a:
#     print (i, i * 2)
# ```
#
# - The `for` loop iterates over the elements of the supplied list, and executes the containing block once for each element. Any kind of list can be used in the `for` loop. For example:

# %%
for v1 in range(10): # by default range start at 0
    print("v1 is :", v1)

# %%
for v2 in range(-1, 11, 2):
    print("v2 is :", v2)

# %%
#list
lotto_numbers = [11, 19, 21, 28, 36, 37]

print("Your number:")
for number in lotto_numbers:
    print(number)

# %%
# string
name = 'KennRY'

for n in name:
    if n.isupper():
        print(n)
    else:
        print(n.upper())

# %% [markdown]
# - `enumerate` keeps track of both the index and the element while iterate through a sequence.

# %%
names = ["Targaryen", "Stark", "Lannister", "Arryn", "Tully", "Greyjoy", "Baratheon", "Tyrell"]

for i, name in enumerate(names):
    print(i, name)

# %% [markdown]
# ### Exercise:
#
# Use a for loop to compute the sum of all the numbers from 7 to 147.

# %% [markdown]
# ### **`while` loops**:
# - The `while` loop executes a set of statements as long as a condition is true.
# - The basic syntax is:
#
# ```python
# val = 1
# while val < 11:
#     print(val)
#     val += 1
# ```

# %%
sum1 = 0
cnt1 = 1

while cnt1 <= 100:
    sum1 += cnt1
    cnt1 += 1
    
print('The sum of all natural numbers from 1 to 100 : ', sum1)
print('The sum of all natural numbers from 1 to 100 : ', sum(range(1, 101)))

# %%
val = 10

while val >0:
    if val %2 == 0 :
        print(val)
    val -= 1

# %% [markdown]
# ### Exercise
#
# Use `while` loop and print all odd numbers between 100 and 110.

# %% [markdown]
# # Credits

# %% [markdown]
# This tutorial is based on material from [Software Carpentry](https://swcarpentry.github.io/python-novice-inflammation/01-intro/index.html).
